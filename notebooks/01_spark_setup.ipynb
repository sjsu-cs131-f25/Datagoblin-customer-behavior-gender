# %%
import sys
print(f"Python version: {sys.version}")
# Out:
# Python version: 3.10.6 (v3.10.6:9c7b4bd164, Aug  1 2022, 17:13:48) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
import subprocess
result = subprocess.run(['java', '-version'], capture_output=True, text=True)
print(result.stderr)
# Out:
# java version "21.0.8" 2025-07-15 LTS
# Java(TM) SE Runtime Environment (build 21.0.8+12-LTS-250)
# Java HotSpot(TM) 64-Bit Server VM (build 21.0.8+12-LTS-250, mixed mode, sharing)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("CS131_Sprint5_DataGoblins_ENG1") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .config("spark.executor.memory", "2g") \
    .getOrCreate()

print(f"✅ Spark session created successfully!")
print(f"Spark version: {spark.version}")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/09 11:51:01 WARN Utils: Your hostname, MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 10.0.0.111 instead (on interface en0)
# 25/11/09 11:51:01 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/09 11:51:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ✅ Spark session created successfully!
# Spark version: 4.0.1

# %%
print("=" * 50)
print("SPARK CONFIGURATION")
print("=" * 50)
print(f"App Name: {spark.sparkContext.appName}")
print(f"Driver Memory: {spark.conf.get('spark.driver.memory')}")
print(f"Shuffle Partitions: {spark.conf.get('spark.sql.shuffle.partitions')}")
print(f"Executor Memory: {spark.conf.get('spark.executor.memory')}")
print("=" * 50)
# Out:
# ==================================================
# SPARK CONFIGURATION
# ==================================================
# App Name: CS131_Sprint5_DataGoblins_ENG1
# Driver Memory: 4g
# Shuffle Partitions: 8
# Executor Memory: 2g
# ==================================================

# %%
customer_df = spark.read.csv("../data/customer_data.csv", header=True, inferSchema=True)

print("✅ Customer data loaded successfully!")
print(f"Total rows: {customer_df.count()}")
print(f"Total columns: {len(customer_df.columns)}")
print("\nSchema:")
customer_df.printSchema()
print("\nFirst 5 rows:")
customer_df.show(5)
# Out:
# ✅ Customer data loaded successfully!
# Total rows: 100000
# Total columns: 12
#
# Schema:
# root
#  |-- id: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- income: integer (nullable = true)
#  |-- education: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- loyalty_status: string (nullable = true)
#  |-- purchase_frequency: string (nullable = true)
#  |-- purchase_amount: integer (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- promotion_usage: integer (nullable = true)
#  |-- satisfaction_score: integer (nullable = true)
#
#
# First 5 rows:
# +---+---+------+------+----------+------+--------------+------------------+---------------+----------------+---------------+------------------+
# | id|age|gender|income| education|region|loyalty_status|purchase_frequency|purchase_amount|product_category|promotion_usage|satisfaction_score|
# +---+---+------+------+----------+------+--------------+------------------+---------------+----------------+---------------+------------------+
# |  1| 27|  Male| 40682|  Bachelor|  East|          Gold|          frequent|          18249|           Books|              0|                 6|
# |  2| 29|  Male| 15317|   Masters|  West|       Regular|              rare|           4557|        Clothing|              1|                 6|
# |  3| 37|  Male| 38849|  Bachelor|  West|        Silver|              rare|          11822|        Clothing|              0|                 6|
# |  4| 30|  Male| 11568|HighSchool| South|       Regular|          frequent|           4098|            Food|              0|                 7|
# |  5| 31|Female| 46952|   College| North|       Regular|        occasional|          19685|        Clothing|              1|                 5|
# +---+---+------+------+----------+------+--------------+------------------+---------------+----------------+---------------+------------------+
# only showing top 5 rows

# %%
print("=" * 50)
print("SPARK CONFIGURATION")
print("=" * 50)
print(f"App Name: {spark.sparkContext.appName}")
print(f"Driver Memory: {spark.conf.get('spark.driver.memory')}")
print(f"Shuffle Partitions: {spark.conf.get('spark.sql.shuffle.partitions')}")
print(f"Executor Memory: {spark.conf.get('spark.executor.memory')}")
print("=" * 50)
# Out:
# ==================================================
# SPARK CONFIGURATION
# ==================================================
# App Name: CS131_Sprint5_DataGoblins_ENG1
# Driver Memory: 4g
# Shuffle Partitions: 8
# Executor Memory: 2g
# ==================================================
